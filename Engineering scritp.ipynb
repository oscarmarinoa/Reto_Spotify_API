# %% [markdown]
# ### First Task

# %%
# Import the necessaty libraries
import pandas as pd

# %%
df = pd.read_json('taylor_swift_spotify.json')
df['albums'][0].keys()
# Out:
# dict_keys(['album_id', 'album_name', 'album_release_date', 'album_total_tracks', 'tracks'])

# %% [markdown]
# disc_number
# duration_ms
# explicit
# track_number
# track_popularity
# track_id
# track_name
# audio_features.danceability	audio_features.energy	audio_features.key	audio_features.loudness	audio_features.mode	audio_features.speechiness	audio_features.acousticness	audio_features.instrumentalness	audio_features.liveness	audio_features.valence	audio_features.tempo	audio_features.id	audio_features.time_signature
# artist_id
# artist_name
# artist_popularity
# album_id
# album_name
# album_release_date
# album_total_tracks

# %%
df.head()
# Out:
#             artist_id   artist_name  artist_popularity  \
# 0  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 1  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 2  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 3  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 4  06HL4z0CvFAxyc27GX  Taylor Swift                120
#
#                                               albums
# 0  {'album_id': '1o59UpKw81iHR0HPiSkJR0', 'album_...
# 1  {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'album_...
# 2  {'album_id': '5AEDGbliTTfjOB8TSm1sxt', 'album_...
# 3  {'album_id': '1fnJ7k0bllNfL1kVdNVW1A', 'album_...
# 4  {'album_id': '3lS1y25WAhcqJDATJK70Mq', 'album_...

# %%
type(df['artist_id'])
# Out:
# pandas.core.series.Series

# %%
df['albums'][0]['tracks'][0]
# Out:
# {'disc_number': 1,
#  'duration_ms': 212600,
#  'explicit': False,
#  'track_number': 1,
#  'audio_features': {'danceability': 0.757,
#   'energy': 0.61,
#   'key': 7,
#   'loudness': -4.84,
#   'mode': 1,
#   'speechiness': 0.0327,
#   'acousticness': 0.009420000000000001,
#   'instrumentalness': 3.66e-05,
#   'liveness': 0.367,
#   'valence': 0.685,
#   'tempo': 116.998,
#   'id': '4WUepByoeqcedHoYhSNHRt',
#   'time_signature': 4},
#  'track_popularity': 77,
#  'track_id': '4WUepByoeqcedHoYhSNHRt',
#  'track_name': "Welcome To New York (Taylor's Version)"}

# %%
type(df['albums'][0])
# Out:
# dict

# %%
df.shape[0]
# Out:
# 27

# %%
df['albums'][0]
# Out:
# {'album_id': '1o59UpKw81iHR0HPiSkJR0',
#  'album_name': "1989 (Taylor's Version) [Deluxe]",
#  'album_release_date': '2023-10-27',
#  'album_total_tracks': 22,
#  'tracks': [{'disc_number': 1,
#    'duration_ms': 212600,
#    'explicit': False,
#    'track_number': 1,
#    'audio_features': {'danceability': 0.757,
#     'energy': 0.61,
#     'key': 7,
#     'loudness': -4.84,
#     'mode': 1,
#     'speechiness': 0.0327,
#     'acousticness': 0.009420000000000001,
#     'instrumentalness': 3.66e-05,
#     'liveness': 0.367,
#     'valence': 0.685,
#     'tempo': 116.998,
#     'id': '4WUepByoeqcedHoYhSNHRt',
#     'time_signature': 4},
#    'track_popularity': 77,
#    'track_id': '4WUepByoeqcedHoYhSNHRt',
#    'track_name': "Welcome To New York (Taylor's Version)"},
#   {'disc_number': 1,
#    'duration_ms': 231833,
#    'explicit': False,
#    'track_number': 2,
#    'audio_features': {'danceability': 0.733,
#     'energy': 0.733,
#     'key': 0,
#     'loudness': -5.376,
# ...

# %%
df['albums'][0].keys()
# Out:
# dict_keys(['album_id', 'album_name', 'album_release_date', 'album_total_tracks', 'tracks'])

# %%
for i in df['albums'][0].keys():
    print(type(df['albums'][0][i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'list'>

# %%
df['albums'][14]['album_name']
# Out:
# 'Lover'

# %%
# for row in range(df.shape[0]):
    
#     for no,column in enumerate(df.columns):
        
#         if type(df[column][row]) == dict:
            
#             for sub_dict in df[column][row].keys():
                
#                 if type(df[column][row][sub_dict]) == list:
                    
#                     for i in df[column][row][sub_dict]:
                        
#                         for j in i.keys():
                        
                        
#                             if type(i[j]) == dict:
                                
#                                 for k in i[j].keys():
                                    
#                                     auxiliar = 'audio_features.' + k
                                    
#                                     dict_taylor[auxiliar].append(i[j][k])
#                                     # print(f'añadí {i[j][k]} en {auxiliar}')
                                    
#                                     # print(f'{k}:')
#                                     # print(i[j][k])
                                    
#                             else:
                                
#                                 dict_taylor[j].append(i[j])
#                                 # print(f'añadí {i[j]} en {j}')
                        
                
#                 else:
                    
#                     dict_taylor[sub_dict].append(df[column][row][sub_dict])
                    
#                 # print(k)
#             # break  
        
#         else:
#             dict_taylor[column].append(df[column][row])

# %%
df['albums'][0]['tracks'][0]['audio_features'].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'time_signature'])

# %%
dict_taylor = {'disc_number': [],
               'duration_ms': [],
               'explicit': [],
               'track_number': [],
               'track_popularity': [],
               'track_id': [], 
               'track_name': [],
               'audio_features.danceability': [], 
               'audio_features.energy': [], 
               'audio_features.key': [], 
               'audio_features.loudness': [], 
               'audio_features.mode': [], 
               'audio_features.speechiness': [], 
               'audio_features.acousticness': [], 
               'audio_features.instrumentalness': [], 
               'audio_features.liveness': [], 
               'audio_features.valence': [], 
               'audio_features.tempo': [], 
               'audio_features.id': [], 
               'audio_features.time_signature': [],
               'artist_id': [],
               'artist_name' : [],
               'artist_popularity' : [],
               'album_id': [], 
               'album_name': [], 
               'album_release_date': [], 
               'album_total_tracks': []}

# %%
df['albums'][0]
# Out:
# {'album_id': '1o59UpKw81iHR0HPiSkJR0',
#  'album_name': "1989 (Taylor's Version) [Deluxe]",
#  'album_release_date': '2023-10-27',
#  'album_total_tracks': 22,
#  'tracks': [{'disc_number': 1,
#    'duration_ms': 212600,
#    'explicit': False,
#    'track_number': 1,
#    'audio_features': {'danceability': 0.757,
#     'energy': 0.61,
#     'key': 7,
#     'loudness': -4.84,
#     'mode': 1,
#     'speechiness': 0.0327,
#     'acousticness': 0.009420000000000001,
#     'instrumentalness': 3.66e-05,
#     'liveness': 0.367,
#     'valence': 0.685,
#     'tempo': 116.998,
#     'id': '4WUepByoeqcedHoYhSNHRt',
#     'time_signature': 4},
#    'track_popularity': 77,
#    'track_id': '4WUepByoeqcedHoYhSNHRt',
#    'track_name': "Welcome To New York (Taylor's Version)"},
#   {'disc_number': 1,
#    'duration_ms': 231833,
#    'explicit': False,
#    'track_number': 2,
#    'audio_features': {'danceability': 0.733,
#     'energy': 0.733,
#     'key': 0,
#     'loudness': -5.376,
# ...

# %%
df.columns
# Out:
# Index(['artist_id', 'artist_name', 'artist_popularity', 'albums'], dtype='object')

# %%
df['artist_name'][0]
# Out:
# 'Taylor Swift'

# %%
df['albums'][0].keys()
# Out:
# dict_keys(['album_id', 'album_name', 'album_release_date', 'album_total_tracks', 'tracks'])

# %%
df['albums'][0]['album_id']
# Out:
# '1o59UpKw81iHR0HPiSkJR0'

# %%
for i in df['albums'][0]['tracks']:
    print(i)
# Out:
# {'disc_number': 1, 'duration_ms': 212600, 'explicit': False, 'track_number': 1, 'audio_features': {'danceability': 0.757, 'energy': 0.61, 'key': 7, 'loudness': -4.84, 'mode': 1, 'speechiness': 0.0327, 'acousticness': 0.009420000000000001, 'instrumentalness': 3.66e-05, 'liveness': 0.367, 'valence': 0.685, 'tempo': 116.998, 'id': '4WUepByoeqcedHoYhSNHRt', 'time_signature': 4}, 'track_popularity': 77, 'track_id': '4WUepByoeqcedHoYhSNHRt', 'track_name': "Welcome To New York (Taylor's Version)"}
# {'disc_number': 1, 'duration_ms': 231833, 'explicit': False, 'track_number': 2, 'audio_features': {'danceability': 0.733, 'energy': 0.733, 'key': 0, 'loudness': -5.376, 'mode': 1, 'speechiness': 0.067, 'acousticness': 5, 'instrumentalness': 0, 'liveness': 0.168, 'valence': 0.7010000000000001, 'tempo': 96.057, 'id': '0108kcWLnn2HlH2kedi1gn', 'time_signature': 4}, 'track_popularity': 78, 'track_id': '0108kcWLnn2HlH2kedi1gn', 'track_name': "Blank Space (Taylor's Version)"}
# ...

# %%
df['albums'][0]['tracks'][0]['audio_features']
# Out:
# {'danceability': 0.757,
#  'energy': 0.61,
#  'key': 7,
#  'loudness': -4.84,
#  'mode': 1,
#  'speechiness': 0.0327,
#  'acousticness': 0.009420000000000001,
#  'instrumentalness': 3.66e-05,
#  'liveness': 0.367,
#  'valence': 0.685,
#  'tempo': 116.998,
#  'id': '4WUepByoeqcedHoYhSNHRt',
#  'time_signature': 4}

# %%
# for row in range(df.shape[0]):
    
#     for column in df.columns:
        
#         if      column == 'artist_id': value_1 = df[column][row]
#         elif    column == 'artist_name': value_2 = df[column][row]
#         elif    column == 'artist_popularity': value_3 = df[column][row]
        
#         if type(df[column][row]) == dict:
            
#             for sub_dict in df[column][row].keys():
                
#                 if      sub_dict == 'album_id': value_4 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_name': value_5 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_release_date': value_6 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_total_tracks': value_7 = df[column][row][sub_dict]
                
#                 if type(df[column][row][sub_dict]) == list:
                    
#                     for lista in df[column][row][sub_dict]:
                        
                        
#                         for s_sub_dict in lista.keys():
                        
                        
#                             if type(lista[s_sub_dict]) == dict:
                                
#                                 for k in lista[s_sub_dict].keys():
                                    
#                                     auxiliar = 'audio_features.' + k
                                    
#                                     dict_taylor[auxiliar].append(lista[s_sub_dict][k])
#                                     dict_taylor['artist_id'].append(value_1)
#                                     dict_taylor['artist_name'].append(value_2)
#                                     dict_taylor['artist_popularity'].append(value_3)
#                                     dict_taylor['album_id'].append(value_4)
#                                     dict_taylor['album_name'].append(value_5)
#                                     dict_taylor['album_release_date'].append(value_6)
#                                     dict_taylor['album_total_tracks'].append(value_7)
                                    
#                             else:
                                
#                                 dict_taylor[s_sub_dict].append(lista[s_sub_dict])
                                
                                
#                 else:
                    
#                     dict_taylor[sub_dict].append(df[column][row][sub_dict])
        
#         # else:
#         #     dict_taylor[column].append(df[column][row])

# %%
df['albums'][0]['tracks'][1]
# Out:
# {'disc_number': 1,
#  'duration_ms': 231833,
#  'explicit': False,
#  'track_number': 2,
#  'audio_features': {'danceability': 0.733,
#   'energy': 0.733,
#   'key': 0,
#   'loudness': -5.376,
#   'mode': 1,
#   'speechiness': 0.067,
#   'acousticness': 5,
#   'instrumentalness': 0,
#   'liveness': 0.168,
#   'valence': 0.7010000000000001,
#   'tempo': 96.057,
#   'id': '0108kcWLnn2HlH2kedi1gn',
#   'time_signature': 4},
#  'track_popularity': 78,
#  'track_id': '0108kcWLnn2HlH2kedi1gn',
#  'track_name': "Blank Space (Taylor's Version)"}

# %%
df['albums']
# Out:
# 0     {'album_id': '1o59UpKw81iHR0HPiSkJR0', 'album_...
# 1     {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'album_...
# 2     {'album_id': '5AEDGbliTTfjOB8TSm1sxt', 'album_...
# 3     {'album_id': '1fnJ7k0bllNfL1kVdNVW1A', 'album_...
# 4     {'album_id': '3lS1y25WAhcqJDATJK70Mq', 'album_...
# 5     {'album_id': '151w1FgRZfnKZA9FEcg9Z3', 'album_...
# 6     {'album_id': '6kZ42qRrzov54LcAk4onW9', 'album_...
# 7     {'album_id': '4hDok0OAJd57SGIT8xuWJH', 'album_...
# 8     {'album_id': '6AORtDjduMM3bupSWzbTSG', 'album_...
# 9     {'album_id': '2Xoteh7uEpea4TohMxjtaq', 'album_...
# 10    {'album_id': '0PZ7lAru5FDFHuirTkWe9Z', 'album_...
# 11    {'album_id': '1pzvBxYgT6OVwJLtHkrdQK', 'album_...
# 12    {'album_id': '2fenSS68JI1h4Fo296JfGr', 'album_...
# 13    {'album_id': '1NAmidJlEaVgA3MpcPFYGq', 'album_...
# 14    {'album_id': '1NAmidJlEaVgA3MpcPFYGq', 'album_...
# 15    {'album_id': '6DEjYFkNZh67HP7R9PSZvv', 'album_...
# 16    {'album_id': '1MPAXuTVL2Ej5x0JHiSPq8', 'album_...
# ...

# %%
# Ciclo para las filas de la tabla principal
for row in range(df.shape[0]):
    
    # Ciclo para las columnas
    for column in df.columns:
        
        # Condicional para el primer diccionario.
        if type(df[column][row]) == dict:
            
            # Ciclo para iterar sobre primer diccionario
            for sub_dict in df[column][row].keys():
                
                if      sub_dict == 'album_id': value_4 = df[column][row][sub_dict]
                elif    sub_dict == 'album_name': value_5 = df[column][row][sub_dict]
                elif    sub_dict == 'album_release_date': value_6 = df[column][row][sub_dict]
                elif    sub_dict == 'album_total_tracks': value_7 = df[column][row][sub_dict]
                
                # Condicional si la clave es otro diccionario
                if type(df[column][row][sub_dict]) == list:
                    
                
                    # Ciclo para iterar en los diccionarios dentro de la lista
                    for no, elemento in enumerate(df[column][row][sub_dict]):
                        
                        for s_sub_dict in elemento.keys(): #df['albums'][0]['tracks'][0].keys()
                            
                            # Condicional si la clave es otro diccionario
                            if type(elemento[s_sub_dict]) == dict:
                                
                            
                                for k in elemento[s_sub_dict].keys():
                                    
                                    auxiliar = 'audio_features.' + k
                                    
                                    dict_taylor[auxiliar].append(elemento[s_sub_dict][k])
                                    # dict_taylor[s_sub_dict].append(df[column][row][sub_dict][no][s_sub_dict])
                                    # dict_taylor['artist_id'].append(value_1)
#                                     dict_taylor['artist_name'].append(value_2)
#                                     dict_taylor['artist_popularity'].append(value_3)
                                    # dict_taylor['album_id'].append(value_4)
#                                     dict_taylor['album_name'].append(value_5)
#                                     dict_taylor['album_release_date'].append(value_6)
#                                     dict_taylor['album_total_tracks'].append(value_7)
                                
                                
                            
                            else:
                                pass
                                dict_taylor[s_sub_dict].append(df[column][row][sub_dict][no][s_sub_dict])
                                # dict_taylor['album_id'].append(value_4)
                                

        #         else:
                    # dict_taylor[sub_dict].append(df[column][row][sub_dict])

        # else:
            # dict_taylor[column].append(df[column][row])

# %%
len(dict_taylor['disc_number'])
# Out:
# 539

# %%
for i in dict_taylor.keys():
    print(len(dict_taylor[i]))
# Out:
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
len(dict_taylor['album_id'])
# Out:
# 0

# %%
# for row in range(df.shape[0]):
    
#     for column in df.columns:
        
#         if      column == 'artist_id': value_1 = df[column][row]
#         elif    column == 'artist_name': value_2 = df[column][row]
#         elif    column == 'artist_popularity': value_3 = df[column][row]
        
#         if type(df[column][row]) == dict:
            
#             for sub_dict in df[column][row].keys():
                
#                 if      sub_dict == 'album_id': value_4 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_name': value_5 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_release_date': value_6 = df[column][row][sub_dict]
#                 elif    sub_dict == 'album_total_tracks': value_7 = df[column][row][sub_dict]
                
#                 if type(df[column][row][sub_dict]) == list:
                    
#                     for lista in df[column][row][sub_dict]:
                        
                        
#                         for s_sub_dict in lista.keys():
                        
                        
#                             if type(lista[s_sub_dict]) == dict:
                                
#                                 for k in lista[s_sub_dict].keys():
                                    
#                                     auxiliar = 'audio_features.' + k
                                    
#                                     dict_taylor[auxiliar].append(lista[s_sub_dict][k])
#                                     dict_taylor['artist_id'].append(value_1)
#                                     dict_taylor['artist_name'].append(value_2)
#                                     dict_taylor['artist_popularity'].append(value_3)
#                                     dict_taylor['album_id'].append(value_4)
#                                     dict_taylor['album_name'].append(value_5)
#                                     dict_taylor['album_release_date'].append(value_6)
#                                     dict_taylor['album_total_tracks'].append(value_7)
                                    
#                             else:
                                
#                                 dict_taylor[s_sub_dict].append(lista[s_sub_dict])
                                
                                
#                 else:
                    
#                     dict_taylor[sub_dict].append(df[column][row][sub_dict])
        
#         # else:
#         #     dict_taylor[column].append(df[column][row])

# %%
for i in dict_taylor.keys():
    print(len(dict_taylor[i]))
# Out:
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df
# Out:
#              artist_id   artist_name  artist_popularity  \
# 0   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 1   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 2   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 3   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 4   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 5   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 6   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 7   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 8   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 9   06HL4z0CvFAxyc27GX  Taylor Swift                120
# 10  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 11  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 12  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 13  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 14  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 15  06HL4z0CvFAxyc27GX  Taylor Swift                120
# ...

# %%
pd.DataFrame.from_dict(dict_taylor)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 pd.DataFrame.from_dict(dict_taylor)
#
# File c:\Users\Oscar Marino\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1763, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1757     raise ValueError(
#    1758         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1759         f"Got '{orient}' instead"
#    1760     )
#    1762 if orient != "tight":
# -> 1763     return cls(data, index=index, columns=columns, dtype=dtype)
#    1764 else:
#    1765     realdata = data["data"]
#
# File c:\Users\Oscar Marino\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
# ...

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [413], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
len(df['albums'][0]['tracks'][0])

# %%
for i in df['albums'][1]['tracks']:
    print(i)

# %%
len(df['albums'][0]['tracks'][0]) # longitud de las llaves en la lista

# %%
# for i in df['albums'][0]['tracks'][0].keys():
#     print(f'{i}:')
#     print(df['albums'][0]['tracks'][0][i])
#     # print(type(i))
#     # print(type(df['albums'][0]['tracks'][0][i]))
    
    
#     if type(df['albums'][0]['tracks'][0][i]) == dict:
#         print('this is dict')
#         for j in df['albums'][0]['tracks'][0][i].keys():
            
#             xxx = 'audio_features.'+j
#             print(f'{j}:')
#             print(df['albums'][0]['tracks'][0][i][j])
#             dict_taylor[xxx].append(df['albums'][0]['tracks'][0][i][j])
        
#     else:
#         dict_taylor[i].append(df['albums'][0]['tracks'][0][i])

# %%
df['albums'][0]

# %%
df['albums'][0]['tracks'][0].keys()

# %%
df['albums'][0]['tracks'][0]['track_id']

# %%
len(df['albums'][0]['tracks'])

# %%
for i in df['albums'][0]['tracks']:
    print(i['duration_ms'])

# %%
len(dict_taylor['audio_features.danceability'])

# %%
len(df['albums'][0]['tracks'])

# %%
df.columns

# %%
# Funciona
n = 1
for i in df['albums'][0]['tracks']:
    
    for j in i.keys():
        
        # print(f'{j}:')
        # print(i[j])

        # print(type(i[j]))
        
        
        if type(i[j]) == dict:
            
            for k in i[j].keys():
                
                auxiliar = 'audio_features.' + k
                
                dict_taylor[auxiliar].append(i[j][k])
                print(f'añadí {i[j][k]} en {auxiliar}')
                
                # print(f'{k}:')
                # print(i[j][k])
                
        else:
            
            dict_taylor[j].append(i[j])
            print(f'añadí {i[j]} en {j}')
            
    print(f'añadimos {n}') 
    print(f'ronda {n}') 
    n += 1

# %%
len(dict_taylor['duration_ms'])

# %%
df

# %%
dict_taylor

# %%
dict_taylor['track_name']

# %%
# for i in df['albums'][0]['tracks'][0].keys():
#     print(f'{i}:')
#     print(df['albums'][0]['tracks'][0][i])
#     # print(type(i))
#     # print(type(df['albums'][0]['tracks'][0][i]))
    
    
#     if type(df['albums'][0]['tracks'][0][i]) == dict:
#         print('this is dict')
#         for j in df['albums'][0]['tracks'][0][i].keys():
            
#             xxx = 'audio_features.'+j
#             print(f'{j}:')
#             print(df['albums'][0]['tracks'][0][i][j])
#             dict_taylor[xxx].append(df['albums'][0]['tracks'][0][i][j])
        
#     else:
#         dict_taylor[i].append(df['albums'][0]['tracks'][0][i])

# %% [markdown]
# ### Task II

# %% [markdown]
# some song names  are empty
#
# some audio_features.loudness are numeric and other not
#
# some audio_features.energy, audio_features.speechines, audio_features.acousticness, audio_features.instrumentalness have over 10 decimals of 0
#
# audio_features.instrumentalness are minus exponential eg. -10**5
#
# some albums names are empty
#
# En album_total_tracks some values are numeric and others are characters
#
# There is some data that is repeated as the album lover that is twice in the dataset
#
# En la columna explicit el tipo de dato es boleano pero hay datos de tipo character eg. no
#
# Album taylor swift release date 1989
