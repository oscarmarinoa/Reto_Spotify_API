# %% [markdown]
# ### Tarea Parte 2: Anomalias

# %%
import pandas as pd
df = pd.read_csv('')

# %% [markdown]
# #### Completitud (Completness)

# %%
# Verificamos la completitud de los datos.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   disc_number                      539 non-null    int64
#  1   duration_ms                      539 non-null    int64
#  2   explicit                         539 non-null    object
#  3   track_number                     539 non-null    int64
#  4   track_popularity                 539 non-null    int64
#  5   track_id                         535 non-null    object
#  6   track_name                       536 non-null    object
#  7   audio_features.danceability      538 non-null    object
#  8   audio_features.energy            537 non-null    float64
#  9   audio_features.key               538 non-null    float64
#  10  audio_features.loudness          537 non-null    float64
#  11  audio_features.mode              539 non-null    int64
#  12  audio_features.speechiness       538 non-null    float64
#  13  audio_features.acousticness      539 non-null    object
#  14  audio_features.instrumentalness  539 non-null    object
#  15  audio_features.liveness          538 non-null    float64
#  16  audio_features.valence           539 non-null    float64
#  17  audio_features.tempo             539 non-null    object
#  18  audio_features.id                539 non-null    object
#  19  audio_features.time_signature    538 non-null    float64
#  20  artist_id                        539 non-null    object
#  21  artist_name                      539 non-null    object
#  22  artist_popularity                539 non-null    int64
#  23  album_id                         539 non-null    object
#  24  album_name                       493 non-null    object
#  25  album_release_date               539 non-null    object
#  26  album_total_tracks               539 non-null    object
# dtypes: float64(7), int64(6), object(14)
# memory usage: 113.8+ KB

# %%
# Es posible evidenciar que ciertas caracteristicas del tipo numérico no son tenidas en cuenta en la función describe. Esto debido a que presentan registros
# del tipo caracter.
df.describe()
# Out:
#        disc_number    duration_ms  track_number  track_popularity  \
# count   539.000000     539.000000    539.000000        539.000000
# mean      1.031540  236003.725417     11.280148         62.918367
# std       0.174934   55019.871010      7.965621         22.498757
# min       1.000000 -223093.000000      1.000000        -92.000000
# 25%       1.000000  209486.500000      5.000000         51.000000
# 50%       1.000000  233626.000000     10.000000         69.000000
# 75%       1.000000  259045.500000     15.000000         77.000000
# max       2.000000  613026.000000     46.000000        152.000000
#
#        audio_features.energy  audio_features.key  audio_features.loudness  \
# count             537.000000          538.000000               537.000000
# mean                0.573065            4.587361                -7.520639
# std                 0.192309            3.246082                 2.933158
# min                 0.118000            0.000000               -17.932000
# 25%                 0.436000            2.000000                -9.287000
# 50%                 0.589000            5.000000                -6.942000
# 75%                 0.729000            7.000000                -5.376000
# max                 0.949000           11.000000                -1.909000
#
#        audio_features.mode  audio_features.speechiness  \
# count           539.000000                  538.000000
# mean              0.912801                    0.057709
# std               0.282388                    0.073146
# min               0.000000                    0.023100
# 25%               1.000000                    0.030525
# 50%               1.000000                    0.037750
# 75%               1.000000                    0.056400
# max               1.000000                    0.912000
#
#        audio_features.liveness  audio_features.valence  \
# count               538.000000              539.000000
# mean                  0.163308                0.398410
# std                   0.141800                0.199409
# min                   0.033500                0.037400
# 25%                   0.096500                0.230000
# 50%                   0.115000                0.386000
# 75%                   0.162250                0.535000
# max                   0.931000                0.943000
#
#        audio_features.time_signature  artist_popularity
# count                     538.000000              539.0
# mean                        3.986989              120.0
# std                         0.197323                0.0
# min                         3.000000              120.0
# 25%                         4.000000              120.0
# 50%                         4.000000              120.0
# 75%                         4.000000              120.0
# max                         5.000000              120.0

# %%
# Caracteristicas del tipo Float con registros NaN (valores no numéricos).
for feature in df[['audio_features.danceability','audio_features.energy','audio_features.key','audio_features.loudness','audio_features.speechiness','audio_features.acousticness','audio_features.instrumentalness',
                   'audio_features.liveness','audio_features.valence','audio_features.tempo','audio_features.time_signature']]:
    display(df[feature][df[feature].isnull()])
# Out:
# 330    None
# Name: audio_features.danceability, dtype: object
# 330   NaN
# 363   NaN
# Name: audio_features.energy, dtype: float64
# 334   NaN
# Name: audio_features.key, dtype: float64
# 330   NaN
# 334   NaN
# Name: audio_features.loudness, dtype: float64
# 330   NaN
# Name: audio_features.speechiness, dtype: float64
# Series([], Name: audio_features.acousticness, dtype: object)
# Series([], Name: audio_features.instrumentalness, dtype: object)
# 341   NaN
# Name: audio_features.liveness, dtype: float64
# Series([], Name: audio_features.valence, dtype: float64)
# Series([], Name: audio_features.tempo, dtype: object)
# 363   NaN
# Name: audio_features.time_signature, dtype: float64

# %%
# Registros vacios en caracteristicas del tipo string
for feature in df[['audio_features.id', 'track_id', 'track_name', 'audio_features.id', 'artist_id', 'artist_name', 'album_id', 'album_name', 'album_release_date']].columns:
    
    print('')
    print(f'columna {feature}:')
    print('')
    
    for i, j  in enumerate(df[feature]):

            if type(j) != str:
                print(f'index: {i} type: {type(j)} formato erroneo')
# Out:
# columna audio_features.id:
#
#
# columna track_id:
#
# index: 363 type: <class 'NoneType'> formato erroneo
# index: 375 type: <class 'NoneType'> formato erroneo
# index: 379 type: <class 'NoneType'> formato erroneo
# index: 382 type: <class 'NoneType'> formato erroneo
#
# columna track_name:
#
# index: 77 type: <class 'NoneType'> formato erroneo
# index: 91 type: <class 'NoneType'> formato erroneo
# index: 104 type: <class 'NoneType'> formato erroneo
#
# columna audio_features.id:
#
#
# columna artist_id:
#
#
# columna artist_name:
#
#
# columna album_id:
#
#
# columna album_name:
#
# index: 329 type: <class 'NoneType'> formato erroneo
# index: 330 type: <class 'NoneType'> formato erroneo
# index: 331 type: <class 'NoneType'> formato erroneo
# index: 332 type: <class 'NoneType'> formato erroneo
# index: 333 type: <class 'NoneType'> formato erroneo
# index: 334 type: <class 'NoneType'> formato erroneo
# index: 335 type: <class 'NoneType'> formato erroneo
# index: 336 type: <class 'NoneType'> formato erroneo
# index: 337 type: <class 'NoneType'> formato erroneo
# index: 338 type: <class 'NoneType'> formato erroneo
# index: 339 type: <class 'NoneType'> formato erroneo
# index: 340 type: <class 'NoneType'> formato erroneo
# index: 341 type: <class 'NoneType'> formato erroneo
# index: 342 type: <class 'NoneType'> formato erroneo
# index: 343 type: <class 'NoneType'> formato erroneo
# index: 344 type: <class 'NoneType'> formato erroneo
# index: 345 type: <class 'NoneType'> formato erroneo
# index: 346 type: <class 'NoneType'> formato erroneo
# index: 347 type: <class 'NoneType'> formato erroneo
# index: 348 type: <class 'NoneType'> formato erroneo
# index: 349 type: <class 'NoneType'> formato erroneo
# index: 350 type: <class 'NoneType'> formato erroneo
# index: 351 type: <class 'NoneType'> formato erroneo
# index: 352 type: <class 'NoneType'> formato erroneo
# index: 353 type: <class 'NoneType'> formato erroneo
# index: 354 type: <class 'NoneType'> formato erroneo
# index: 355 type: <class 'NoneType'> formato erroneo
# index: 356 type: <class 'NoneType'> formato erroneo
# index: 357 type: <class 'NoneType'> formato erroneo
# index: 358 type: <class 'NoneType'> formato erroneo
# index: 359 type: <class 'NoneType'> formato erroneo
# index: 360 type: <class 'NoneType'> formato erroneo
# index: 361 type: <class 'NoneType'> formato erroneo
# index: 362 type: <class 'NoneType'> formato erroneo
# index: 363 type: <class 'NoneType'> formato erroneo
# index: 364 type: <class 'NoneType'> formato erroneo
# index: 365 type: <class 'NoneType'> formato erroneo
# index: 366 type: <class 'NoneType'> formato erroneo
# index: 367 type: <class 'NoneType'> formato erroneo
# index: 368 type: <class 'NoneType'> formato erroneo
# index: 369 type: <class 'NoneType'> formato erroneo
# index: 370 type: <class 'NoneType'> formato erroneo
# index: 371 type: <class 'NoneType'> formato erroneo
# index: 372 type: <class 'NoneType'> formato erroneo
# index: 373 type: <class 'NoneType'> formato erroneo
# index: 374 type: <class 'NoneType'> formato erroneo
#
# columna album_release_date:

# %% [markdown]
# #### Unicidad (Uniqueness)

# %%
# Dimensiones iniciales del set de datos.
print(f'Dimensiones iniciales: {df.shape}')
print(f'Dataset sin registros repetidos: {df.drop_duplicates().shape}. No tiene en cuenta la fila que tiene el registro con formato erroneo')
print(f'Registros repetidos: {df[df.duplicated() == True].shape}. No tiene en cuenta la fila que tiene el registro con formato erroneo')
print('')
print('Ejemplo de algunos registros repetidos:')
display(df[df.duplicated() == True][['artist_name', 'album_name','track_name']].sort_values(by= 'track_name').sample(10))

# Dado a que en la característica "explicit" hay un error en el formato de la casilla el registro es considerado como diferente, sin embargo, 
# al corregir esto podemos evidenciar que es un registro adicional repetido.
df[(df['album_name'] == 'Lover') &  (df['track_name'] == 'Cruel Summer')][['explicit', 'album_name', 'track_name']].sort_values(by= 'track_name')
# Out:
# Dimensiones iniciales: (539, 27)
# Dataset sin registros repetidos: (521, 27). No tiene en cuenta la fila que tiene el registro con formato erroneo
# Registros repetidos: (18, 27). No tiene en cuenta la fila que tiene el registro con formato erroneo
#
# Ejemplo de algunos registros repetidos:
#       artist_name                        album_name  \
# 302  Taylor Swift                             Lover
# 299  Taylor Swift                             Lover
# 300  Taylor Swift                             Lover
# 306  Taylor Swift                             Lover
# 310  Taylor Swift                             Lover
# 88   Taylor Swift  Midnights (The Til Dawn Edition)
# 311  Taylor Swift                             Lover
# 305  Taylor Swift                             Lover
# 307  Taylor Swift                             Lover
# 304  Taylor Swift                             Lover
#
#                                           track_name
# 302                                      Paper Rings
# 299                                       The Archer
# 300                                 I Think He Knows
# 306        Soon You’ll Get Better (feat. The Chicks)
# 310  ME! (feat. Brendon Urie of Panic! At The Disco)
# 88                                    Hits Different
# 311                       It’s Nice To Have A Friend
# 305                                       London Boy
# 307                                        False God
# 304                         Death By A Thousand Cuts
#     explicit album_name    track_name
# 278    False      Lover  Cruel Summer
# 296       No      Lover  Cruel Summer

# %%
# Indices de registros duplicados sin tener en cuenta el registro 296 que también es una copia.
df[df.duplicated() == True][['artist_name', 'album_name','track_name']].index
# Out:
# Int64Index([ 88, 295, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307,
#             308, 309, 310, 311, 312],
#            dtype='int64')

# %%
# Tanto la caracteristica track_id como audio_features.id (endpoits Track y Track's Audio Features), hacen referencia a la misma información.
# Sin embargo, dado que track_id tiene ciertas casillas vacias algunos registros pueden ser tomados como diferentes.
df[['track_id', 'audio_features.id']]
# Out:
#                    track_id       audio_features.id
# 0    4WUepByoeqcedHoYhSNHRt  4WUepByoeqcedHoYhSNHRt
# 1    0108kcWLnn2HlH2kedi1gn  0108kcWLnn2HlH2kedi1gn
# 2    3Vpk1hfMAQme8VJ0SNRSkd  3Vpk1hfMAQme8VJ0SNRSkd
# 3    1OcSfkeCg9hRC2sFKB4IMJ  1OcSfkeCg9hRC2sFKB4IMJ
# 4    2k0ZEeAqzvYMcx9Qt5aClQ  2k0ZEeAqzvYMcx9Qt5aClQ
# ..                      ...                     ...
# 534  1j6gmK6u4WNI33lMZ8dC1s  1j6gmK6u4WNI33lMZ8dC1s
# 535  7CzxXgQXurKZCyHz9ufbo1  7CzxXgQXurKZCyHz9ufbo1
# 536  1k3PzDNjg38cWqOvL4M9vq  1k3PzDNjg38cWqOvL4M9vq
# 537  0YgHuReCSPwTXYny7isLja  0YgHuReCSPwTXYny7isLja
# 538  1hxLyjC9D9Jpw6EAPKqWv4  1hxLyjC9D9Jpw6EAPKqWv4
#
# [539 rows x 2 columns]

# %%
df[df['track_id'].isnull() == True]
# Out:
#      disc_number  duration_ms explicit  track_number  track_popularity  \
# 363            1       238093    False            35                32
# 375            1       212600    False             1                60
# 379            1       193293    False             5                60
# 382            1       211933    False             8                61
#
#     track_id                  track_name audio_features.danceability  \
# 363     None              Jump Then Fall                       0.617
# 375     None         Welcome To New York                       0.789
# 379     None  All You Had To Do Was Stay                       0.605
# 382     None                   Bad Blood                       0.646
#
#      audio_features.energy  audio_features.key  ...  audio_features.tempo  \
# 363                    NaN                 2.0  ...                80.007
# 375                  0.634                 7.0  ...               116.992
# 379                  0.725                 5.0  ...                 96.97
# 382                  0.794                 7.0  ...               170.216
#
#           audio_features.id  audio_features.time_signature  \
# 363  5zytSTR2g0I9psX2Z12ex6                            NaN
# 375  3nRmDz7qGCvsMS30rGGY0x                            4.0
# 379  6aLOekfwbytwWvQftxTEF0                            4.0
# 382  2NlmmAjGYrrjAp0MED5rGx                            4.0
#
#               artist_id   artist_name  artist_popularity  \
# 363  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 375  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 379  06HL4z0CvFAxyc27GX  Taylor Swift                120
# 382  06HL4z0CvFAxyc27GX  Taylor Swift                120
#
#                    album_id     album_name album_release_date  \
# 363  1MPAXuTVL2Ej5x0JHiSPq8           None         2017-11-09
# 375  1yGbNOtRIgdIiGHOEBaZWf  1989 (Deluxe)         2014-01-01
# 379  1yGbNOtRIgdIiGHOEBaZWf  1989 (Deluxe)         2014-01-01
# 382  1yGbNOtRIgdIiGHOEBaZWf  1989 (Deluxe)         2014-01-01
#
#      album_total_tracks
# 363                  46
# 375                  19
# 379                  19
# 382                  19
#
# [4 rows x 27 columns]

# %%
df['track_id'][442]
# Out:
# ''

# %% [markdown]
# #### Validez (Validity)

# %%
# Tipo de datos
df.dtypes
# Out:
# disc_number                          int64
# duration_ms                          int64
# explicit                            object
# track_number                         int64
# track_popularity                     int64
# track_id                            object
# track_name                          object
# audio_features.danceability         object
# audio_features.energy              float64
# audio_features.key                 float64
# audio_features.loudness            float64
# audio_features.mode                  int64
# audio_features.speechiness         float64
# audio_features.acousticness         object
# audio_features.instrumentalness     object
# audio_features.liveness            float64
# audio_features.valence             float64
# audio_features.tempo                object
# audio_features.id                   object
# audio_features.time_signature      float64
# artist_id                           object
# artist_name                         object
# artist_popularity                    int64
# album_id                            object
# album_name                          object
# album_release_date                  object
# album_total_tracks                  object
# dtype: object

# %%
# El formato de los datos de la columna explicit, es del tipo booleano, sin embargo, algunos de los datos son de tipo caracter.
print(df['explicit'].value_counts())

# Debido esto genera que registros que se encuentran repetidos sean tomados como diferentes.
df[(df['album_name'] == 'Lover') &  (df['track_name'] == 'Cruel Summer')][['explicit', 'album_name', 'track_name']].sort_values(by= 'track_name')
# Out:
# False    480
# True      54
# No         4
# Si         1
# Name: explicit, dtype: int64
#     explicit album_name    track_name
# 278    False      Lover  Cruel Summer
# 296       No      Lover  Cruel Summer

# %%
for no,record in enumerate(df['explicit']):
    if type(record)  != bool:
        print(f'Indice: {no} valor registros: {record}')
# Out:
# Indice: 199 valor registros: Si
# Indice: 200 valor registros: No
# Indice: 250 valor registros: No
# Indice: 296 valor registros: No
# Indice: 360 valor registros: No

# %%
# Tipo de dato erroneo en caracteristicas del tipo flotante
for feature in df[['audio_features.danceability', 'audio_features.acousticness', 'audio_features.instrumentalness', 'audio_features.tempo']].columns:
    
    print('')
    print(f'columna {feature}:')
    print('')
    
    for i, j  in enumerate(df[feature]):

            if feature == 'audio_features.instrumentalness' and j == 0:
                pass
            elif type(j) != float:
                print(f'index: {i} type: {type(j)} formato erroneo')
# Out:
# columna audio_features.danceability:
#
# index: 330 type: <class 'NoneType'> formato erroneo
# index: 431 type: <class 'str'> formato erroneo
#
# columna audio_features.acousticness:
#
# index: 1 type: <class 'int'> formato erroneo
# index: 431 type: <class 'str'> formato erroneo
# index: 535 type: <class 'int'> formato erroneo
#
# columna audio_features.instrumentalness:
#
# index: 524 type: <class 'str'> formato erroneo
#
# columna audio_features.tempo:
#
# index: 432 type: <class 'str'> formato erroneo

# %%
cantidad = 0
for i, j in enumerate(df['album_total_tracks']):
    if type(j) != int:
        cantidad +=1
        print(f'index: {i} type: {type(j)} formato erroneo')
print(f'Cantidad de registros con el formato erroneo: {cantidad}')
# Out:
# index: 524 type: <class 'str'> formato erroneo
# index: 525 type: <class 'str'> formato erroneo
# index: 526 type: <class 'str'> formato erroneo
# index: 527 type: <class 'str'> formato erroneo
# index: 528 type: <class 'str'> formato erroneo
# index: 529 type: <class 'str'> formato erroneo
# index: 530 type: <class 'str'> formato erroneo
# index: 531 type: <class 'str'> formato erroneo
# index: 532 type: <class 'str'> formato erroneo
# index: 533 type: <class 'str'> formato erroneo
# index: 534 type: <class 'str'> formato erroneo
# index: 535 type: <class 'str'> formato erroneo
# index: 536 type: <class 'str'> formato erroneo
# index: 537 type: <class 'str'> formato erroneo
# index: 538 type: <class 'str'> formato erroneo
# Cantidad de registros con el formato erroneo: 15

# %%
# Registros por fuera del rango apropiado.
for feature in df[['audio_features.acousticness', 'artist_popularity', 'audio_features.danceability', 'audio_features.key', 'audio_features.energy',
                   'audio_features.valence', 'audio_features.time_signature']]:
    print('')
    print(f'columna {feature}:')
    for no, record in enumerate(df[feature]):
        try:
            if feature in ['audio_features.danceability',  'audio_features.energy', 'audio_features.acousticness', 'audio_features.valence']:
                if record < 0 or record > 1:
                    print(f'index: {no} valor: {record} rango erroneo')               
            elif feature == 'audio_features.key':
                if record < -1 or record > 11:
                    print(f'index: {no} valor: {record} rango erroneo')                
            elif feature == 'audio_features.time_signature':
                if record < 3 or record > 7:
                    print(f'index: {no} valor: {record} rango erroneo')
            else:
                if record < 0 or record > 100:
                    print(f'index: {no} valor: {record} rango erroneo')
        except:
            pass
# Out:
# columna audio_features.acousticness:
# index: 1 valor: 5 rango erroneo
# index: 3 valor: -0.000537 rango erroneo
# index: 6 valor: -0.00354 rango erroneo
# index: 527 valor: 1.5 rango erroneo
# index: 535 valor: 2 rango erroneo
#
# columna artist_popularity:
# index: 0 valor: 120 rango erroneo
# index: 1 valor: 120 rango erroneo
# index: 2 valor: 120 rango erroneo
# index: 3 valor: 120 rango erroneo
# index: 4 valor: 120 rango erroneo
# index: 5 valor: 120 rango erroneo
# index: 6 valor: 120 rango erroneo
# index: 7 valor: 120 rango erroneo
# index: 8 valor: 120 rango erroneo
# index: 9 valor: 120 rango erroneo
# index: 10 valor: 120 rango erroneo
# index: 11 valor: 120 rango erroneo
# index: 12 valor: 120 rango erroneo
# index: 13 valor: 120 rango erroneo
# index: 14 valor: 120 rango erroneo
# index: 15 valor: 120 rango erroneo
# index: 16 valor: 120 rango erroneo
# index: 17 valor: 120 rango erroneo
# index: 18 valor: 120 rango erroneo
# index: 19 valor: 120 rango erroneo
# index: 20 valor: 120 rango erroneo
# index: 21 valor: 120 rango erroneo
# index: 22 valor: 120 rango erroneo
# index: 23 valor: 120 rango erroneo
# index: 24 valor: 120 rango erroneo
# index: 25 valor: 120 rango erroneo
# index: 26 valor: 120 rango erroneo
# index: 27 valor: 120 rango erroneo
# index: 28 valor: 120 rango erroneo
# index: 29 valor: 120 rango erroneo
# index: 30 valor: 120 rango erroneo
# index: 31 valor: 120 rango erroneo
# index: 32 valor: 120 rango erroneo
# index: 33 valor: 120 rango erroneo
# index: 516 valor: 120 rango erroneo
# index: 517 valor: 120 rango erroneo
# index: 518 valor: 120 rango erroneo
# index: 519 valor: 120 rango erroneo
# index: 520 valor: 120 rango erroneo
# index: 521 valor: 120 rango erroneo
# index: 522 valor: 120 rango erroneo
# index: 523 valor: 120 rango erroneo
# index: 524 valor: 120 rango erroneo
# index: 525 valor: 120 rango erroneo
# index: 526 valor: 120 rango erroneo
# index: 527 valor: 120 rango erroneo
# index: 528 valor: 120 rango erroneo
# index: 529 valor: 120 rango erroneo
# index: 530 valor: 120 rango erroneo
# index: 531 valor: 120 rango erroneo
# index: 532 valor: 120 rango erroneo
# index: 533 valor: 120 rango erroneo
# index: 534 valor: 120 rango erroneo
# index: 535 valor: 120 rango erroneo
# index: 536 valor: 120 rango erroneo
# index: 537 valor: 120 rango erroneo
# index: 538 valor: 120 rango erroneo
#
# columna audio_features.danceability:
#
# columna audio_features.key:
#
# columna audio_features.energy:
#
# columna audio_features.valence:
#
# columna audio_features.time_signature:

# %%
# Tipo de dato erroneo en caracteristicas del tipo string
for feature in df[['audio_features.id', 'track_id', 'track_name', 'audio_features.id', 'artist_id', 'artist_name', 'album_id', 'album_name', 'album_release_date']].columns:
    print('')
    print(f'columna {feature}:')
    
    for i, j  in enumerate(df[feature]):
            if type(j) != str:
                print(f'index: {i} type: {type(j)} formato erroneo')
# Out:
# columna audio_features.id:
#
# columna track_id:
# index: 363 type: <class 'NoneType'> formato erroneo
# index: 375 type: <class 'NoneType'> formato erroneo
# index: 379 type: <class 'NoneType'> formato erroneo
# index: 382 type: <class 'NoneType'> formato erroneo
#
# columna track_name:
# index: 77 type: <class 'NoneType'> formato erroneo
# index: 91 type: <class 'NoneType'> formato erroneo
# index: 104 type: <class 'NoneType'> formato erroneo
#
# columna audio_features.id:
#
# columna artist_id:
#
# columna artist_name:
#
# columna album_id:
#
# columna album_name:
# index: 329 type: <class 'NoneType'> formato erroneo
# index: 330 type: <class 'NoneType'> formato erroneo
# index: 331 type: <class 'NoneType'> formato erroneo
# index: 332 type: <class 'NoneType'> formato erroneo
# index: 333 type: <class 'NoneType'> formato erroneo
# index: 334 type: <class 'NoneType'> formato erroneo
# index: 335 type: <class 'NoneType'> formato erroneo
# index: 336 type: <class 'NoneType'> formato erroneo
# index: 337 type: <class 'NoneType'> formato erroneo
# index: 338 type: <class 'NoneType'> formato erroneo
# index: 339 type: <class 'NoneType'> formato erroneo
# index: 340 type: <class 'NoneType'> formato erroneo
# index: 341 type: <class 'NoneType'> formato erroneo
# index: 342 type: <class 'NoneType'> formato erroneo
# index: 343 type: <class 'NoneType'> formato erroneo
# index: 344 type: <class 'NoneType'> formato erroneo
# index: 345 type: <class 'NoneType'> formato erroneo
# index: 346 type: <class 'NoneType'> formato erroneo
# index: 347 type: <class 'NoneType'> formato erroneo
# index: 348 type: <class 'NoneType'> formato erroneo
# index: 349 type: <class 'NoneType'> formato erroneo
# index: 350 type: <class 'NoneType'> formato erroneo
# index: 351 type: <class 'NoneType'> formato erroneo
# index: 352 type: <class 'NoneType'> formato erroneo
# index: 353 type: <class 'NoneType'> formato erroneo
# index: 354 type: <class 'NoneType'> formato erroneo
# index: 355 type: <class 'NoneType'> formato erroneo
# index: 356 type: <class 'NoneType'> formato erroneo
# index: 357 type: <class 'NoneType'> formato erroneo
# index: 358 type: <class 'NoneType'> formato erroneo
# index: 359 type: <class 'NoneType'> formato erroneo
# index: 360 type: <class 'NoneType'> formato erroneo
# index: 361 type: <class 'NoneType'> formato erroneo
# index: 362 type: <class 'NoneType'> formato erroneo
# index: 363 type: <class 'NoneType'> formato erroneo
# index: 364 type: <class 'NoneType'> formato erroneo
# index: 365 type: <class 'NoneType'> formato erroneo
# index: 366 type: <class 'NoneType'> formato erroneo
# index: 367 type: <class 'NoneType'> formato erroneo
# index: 368 type: <class 'NoneType'> formato erroneo
# index: 369 type: <class 'NoneType'> formato erroneo
# index: 370 type: <class 'NoneType'> formato erroneo
# index: 371 type: <class 'NoneType'> formato erroneo
# index: 372 type: <class 'NoneType'> formato erroneo
# index: 373 type: <class 'NoneType'> formato erroneo
# index: 374 type: <class 'NoneType'> formato erroneo
#
# columna album_release_date:

# %%
# Los registros de track_id son de 22 caracteres, algunos registros son del tipo string pero se encuentran vacíos.
for no, record in enumerate(df['track_id']):
    try:
        if len(record) < 22:
            print(f'Index: {no}, registro: {record}')
    except: 
        pass
# Out:
# Index: 321, registro:
# Index: 434, registro:
# Index: 442, registro:
# Index: 445, registro:

# %% [markdown]
# ### Precisión (Accuracy)

# %%
# Número real de canciones por álbum.
df['album_name'].value_counts(sort=False).sort_index()
# Out:
#                                                                                        16
# 1989                                                                                   13
# 1989 (Deluxe)                                                                          19
# 1989 (Taylor's Version)                                                                21
# 1989 (Taylor's Version) [Deluxe]                                                       22
# Fearless (International Version)                                                       16
# Fearless (Platinum Edition)                                                            19
# Fearless (Taylor's Version)                                                            26
# Live From Clear Channel Stripped 2008                                                   8
# Lover                                                                                  36
# Midnights                                                                              13
# Midnights (3am Edition)                                                                20
# Midnights (The Til Dawn Edition)                                                       24
# Red (Deluxe Edition)                                                                   22
# Red (Taylor's Version)                                                                 30
# Speak Now                                                                              14
# Speak Now (Deluxe Package)                                                             22
# Speak Now (Taylor's Version)                                                           22
# Taylor Swift                                                                           15
# evermore                                                                               15
# evermore (deluxe version)                                                              17
# folklore                                                                               16
# folklore (deluxe version)                                                              17
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    34
# reputation                                                                             16
# Name: album_name, dtype: int64

# %%
# Número de canciones por álbum según el set de datos
df[['album_name','album_total_tracks']].drop_duplicates().sort_values(by='album_name')
# Out:
#                                             album_name album_total_tracks
# 429                                                                    16
# 394                                               1989                 13
# 375                                      1989 (Deluxe)                 19
# 22                             1989 (Taylor's Version)                 21
# 0                     1989 (Taylor's Version) [Deluxe]                 22
# 500                   Fearless (International Version)                 16
# 481                        Fearless (Platinum Edition)                 19
# 152                        Fearless (Taylor's Version)                 26
# 516              Live From Clear Channel Stripped 2008                  8
# 277                                              Lover                 18
# 109                                          Midnights                 13
# 89                             Midnights (3am Edition)                 20
# 65                    Midnights (The Til Dawn Edition)                 24
# 407                               Red (Deluxe Edition)                 22
# 122                             Red (Taylor's Version)                 34
# 445                                          Speak Now                 14
# 459                         Speak Now (Deluxe Package)                 22
# 43                        Speak Now (Taylor's Version)                 22
# 524                                       Taylor Swift           Thirteen
# 195                                           evermore                 10
# 178                          evermore (deluxe version)                 17
# 261                                           folklore                 16
# 244                          folklore (deluxe version)                 17
# 210  folklore: the long pond studio sessions (from ...                 34
# 313                                         reputation                 15
# 329                                               None                 46

# %%
# Indices de los registros con valores erroneos en el numero de canciones por album.
df[(df['album_name'] == 'Red (taylor’s versión)') | (df['album_name'] == 'evermore') |  (df['album_name'] == 'Lover') | (df['album_name'] == 'reputation') | (df['album_name'] == 'Taylor Swift')].index
# Out:
# Int64Index([195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207,
#             208, 209, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287,
#             288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300,
#             301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313,
#             314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326,
#             327, 328, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534,
#             535, 536, 537, 538],
#            dtype='int64')

# %%
from datetime import datetime

# %%
# Álbumes con fecha de estreno erroneo.
print('Numero de registros con fechas de estreno del album por fuera de las fechas reales de lanzamiento:')
print(df[['album_release_date', 'album_name', 'album_id', 'track_name']][(df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) < 2006) |
                                                                   (df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) > 2024)].shape[0])
print('Algunos ejemplos son:')
df[['album_release_date', 'album_name', 'album_id', 'track_name']][(df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) < 2006) |
                                                                   (df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) > 2024)].sample(10)
# Out:
# Numero de registros con fechas de estreno del album por fuera de las fechas reales de lanzamiento:
# 39
# Algunos ejemplos son:
#     album_release_date                        album_name  \
# 82          2027-05-26  Midnights (The Til Dawn Edition)
# 75          2027-05-26  Midnights (The Til Dawn Edition)
# 77          2027-05-26  Midnights (The Til Dawn Edition)
# 85          2027-05-26  Midnights (The Til Dawn Edition)
# 529         1989-10-24                      Taylor Swift
# 535         1989-10-24                      Taylor Swift
# 65          2027-05-26  Midnights (The Til Dawn Edition)
# 81          2027-05-26  Midnights (The Til Dawn Edition)
# 83          2027-05-26  Midnights (The Til Dawn Edition)
# 537         1989-10-24                      Taylor Swift
#
#                    album_id                     track_name
# 82   1fnJ7k0bllNfL1kVdNVW1A                         Glitch
# 75   1fnJ7k0bllNfL1kVdNVW1A                          Karma
# 77   1fnJ7k0bllNfL1kVdNVW1A                           None
# 85   1fnJ7k0bllNfL1kVdNVW1A                 Hits Different
# 529  5eyZZoQEFQWRHkV2xgAeBw                    The Outside
# 535  5eyZZoQEFQWRHkV2xgAeBw  I'm Only Me When I'm With You
# 65   1fnJ7k0bllNfL1kVdNVW1A                  Lavender Haze
# 81   1fnJ7k0bllNfL1kVdNVW1A                High Infidelity
# 83   1fnJ7k0bllNfL1kVdNVW1A  Would've, Could've, Should've
# 537  5eyZZoQEFQWRHkV2xgAeBw         A Perfectly Good Heart

# %%
# Indices de álbumes con fecha de estreno erroneo.
df[['album_release_date', 'album_name', 'album_id', 'track_name']][(df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) < 2006) |
                                                                   (df['album_release_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year) > 2024)].index
# Out:
# Int64Index([ 65,  66,  67,  68,  69,  70,  71,  72,  73,  74,  75,  76,  77,
#              78,  79,  80,  81,  82,  83,  84,  85,  86,  87,  88, 524, 525,
#             526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538],
#            dtype='int64')
